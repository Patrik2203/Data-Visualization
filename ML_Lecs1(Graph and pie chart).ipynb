# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
file = pd.read_excel('C:\\Users\\prince shukla\\Desktop\\Pratik Shukla PU\\Python Program\\ML\\Data.csv.xlsx')
file
# Out:
#        Label  Value  X Values  Y Values
# 0      Apple     10        10         1
# 1     Banana     15        20         5
# 2     Orange      7        30         7
# 3     Grapes     12        40         3
# 4  Pineapple     13        50         6

# %%
x_axis = file["X Values"]
y_axis = file["Y Values"]

# %%
plt.bar(x_axis, y_axis, width = 5, color = "blue")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.show()

# %%
file = pd.read_excel('C:\\Users\\prince shukla\\Desktop\\Pratik Shukla PU\\Python Program\\ML\\Data.csv.xlsx')
plt.pie(file['Value'], labels = file['Label'])
plt.show()
